# %% [markdown]
# <a href="https://colab.research.google.com/github/yesesswi-whjr/c110/blob/main/110hw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
filetoupload=files.upload()
# Out:
#      <input type="file" id="files-761bbe65-53a4-4f8c-aec7-cc7dcd9b0db9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-761bbe65-53a4-4f8c-aec7-cc7dcd9b0db9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving medium_data.csv to medium_data.csv

# %%
import random
import pandas as pd
import plotly.figure_factory as ff
import statistics
import csv
df=pd.read_csv("medium_data.csv")
data=df["id"].tolist()

mean=statistics.mean(data)
print(mean)
sd=statistics.stdev(data)
print(sd)
fig=ff.create_distplot([data],["id"],show_hist=False)
fig.show()
# Out:
# 3254.5
# 1878.8421079661448
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
dataset=[]
for i in range(0,100):
  randomindex=random.randint(0,len(data))
  value=data[randomindex]
  dataset.append(value)

# %%
def randomsetofmean(counter):
  dataset=[]
  for i in range(0,counter):
    randomindex=random.randint(0,len(data)-1)
    value=data[randomindex]
    dataset.append(value)
  mean=statistics.mean(dataset)
  return mean

def showfig(meanlist):
  df=meanlist
  fig=ff.create_distplot([df],["id"],show_hist=False)
  fig.show()

def setup():
  meanlist=[]
  for i in range(0,100):
    setofmeans=randomsetofmean(30)
    meanlist.append(setofmeans)
  mean=statistics.mean(meanlist)
  sd=statistics.stdev(meanlist)
  print(mean,sd)
  showfig(meanlist)
setup()
# Out:
# 3236.529666666667 342.61844237741616
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
